# %%
from sympy import *
from sympy.plotting import plot 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sympy.plotting.plot import MatplotlibBackend

# %%
x, y=symbols('x y')
eq=1/pi/sqrt(sin(y/2)**2-sin(x/2)**2)
I=integrate(eq, (x,0, pi/2))-1

# %%
plt.figure(figsize=(2.97*5,2.1*5, dpi=300) # размер графика
plt.xlabel=r"$ \varphi_m $"
plt.ylabel="$ \Delta T /T_0 $"
plt.grid(True, linestyle="--") # сетка
#plt.axis([0,0.25,0,1.3]) # масштабы осей
x_a = np.linspace(0,2.9,200)
plt.plot(x_a, I.evalf(5,subs={y:x_a}), "-r",linewidth=1, label="Линейная аппроксимация $u = %.2f v + %.2f$" % (k, a)) # аппроксимация
plt.legend() # легенда
